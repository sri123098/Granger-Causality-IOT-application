# %%
# %matplotlib notebook
import numpy as np
import time
import matplotlib.pyplot as plt
import scipy.stats as sc
import serial
import pandas as pd

# %%
from serial import Serial
# ser.close()
ser = serial.Serial('COM4', 9600)

# %% [markdown]
# # Verification whether sensors are working fine or not.

# %%
# Right now, I'm smapling the data five times in a second. So, the reads are not properly getting the data. 
for i in range(15):
    ser.close()
    ser.open()
    time.sleep(0.3)
    ser_bytes=ser.readline()
#     print(ser_bytes[0:len(ser_bytes)-2].decode("utf-8"))
    print(ser_bytes)
#     time.sleep(0.3)
# Out:
# b'\t286\t279\t285\t309\t310\r\n'
# b'\t286\t279\t285\t310\t311\r\n'
# b'\t287\t280\t285\t310\t311\r\n'
# b'\t287\t280\t285\t321\t304\r\n'
# b'\t287\t280\t286\t635\t272\r\n'
# b'\t288\t281\t287\t635\t266\r\n'
# b'\t289\t281\t287\t348\t243\r\n'
# b'\t290\t282\t288\t637\t413\r\n'
# b'\t289\t283\t289\t637\t373\r\n'
# b'\t290\t283\t289\t316\t635\r\n'
# b'\t291\t283\t290\t266\t634\r\n'
# b'\t291\t284\t290\t257\t634\r\n'
# b'\t291\t285\t291\t251\t276\r\n'
# b'\t552\t631\t308\t250\t265\r\n'
# b'\t630\t630\t284\t251\t260\r\n'

# %%
k=ser_bytes
print(ser_bytes.split())
print(int(ser_bytes.split()[2])) 
print(len( ser_bytes.split()  ))
#         sensor2.append(int(ser_bytes.split()[1]))
# Out:
# [b'634', b'237', b'227']
# 227
# 3

# %%
#Angles to be passed to the servo motor
# ser1.write(bytes([err_angle]))
# old_angle1 = int.from_bytes(ser1.readline(), byteorder='little')


# This is the code for the serial read and write.
# i=0
# for modem in PortList:
#     for port in modem:
#         try:
#             ser = serial.Serial(port, 9600, timeout=1)
#             ser.close()
#             ser.open()
#             ser.write("ati")
#             time.sleep(3)
#             read_val = ser.read(size=64)
#             print read_val
#             if read_val is not '':
#                 print port
#         except serial.SerialException:
#             continue
#         i+=1

# ser.flushInput()
# fig = plt.figure(figsize=(9,5))
# ax = fig.add_subplot(111)
# ax.set_title("Moisture for " +str(len( ser_bytes.split() ))+ " sensors")
# ax.set_xlabel('time (s)')
# ax.set_ylabel('Moisture')
# # If there are five sensors, based on the serial data it should automately define the lists.
# dict_map={}
# for i in range(len( ser_bytes.split()  )):
#     dict_map[i]=[]


# timelog=[]
# start = time.time()
# while True:
#     try:
# #         ser_bytes = ser.readline()
# #         ser_bytes = ser.readline()
#         #No need of the above hack as I'm allocating the time.  
#         ser.close()
#         ser.open()
#         ser_bytes = ser.readline()
#         timelog.append(round(time.time()- start, 2)) 
#         for i in range(len(ser_bytes.split())):
#             dict_map[i].append(int(ser_bytes.split()[i]))
#             ax.clear()
#             ax.plot(timelog, dict_map[i] ,label="sensor "+ str(i))        
#             ax.legend(loc='upper right')
#             ax.set_title("Moisture for " +str(len( ser_bytes.split() ))+ " sensors")
#             ax.set_xlabel('time (s)')
#             ax.set_ylabel('Moisture')
#         fig.canvas.draw()   
#     except KeyboardInterrupt:
#         print("Keyboard Interrupt")
#         break

# %% [markdown]
# # Checking for 3 sensors

# %%
#this is the code if you have only 3 sensors.
ser.flushInput()
fig = plt.figure(figsize=(9,5))
ax = fig.add_subplot(111)
ax.set_title("Moisture")
ax.set_xlabel('time (s)')
ax.set_ylabel('Moisture')
sensor1=[]
sensor2=[]
sensor3=[]
# sensor4=[]
# sensor5=[]
timelog=[]
start = time.time()
while True:
    try:
        ser_bytes = ser.readline()
        ser.close()
        ser.open()
        sensor1.append(int(ser_bytes.split()[0])) 
        sensor2.append(int(ser_bytes.split()[1]))
        sensor3.append(int(ser_bytes.split()[2]))
        timelog.append(round(time.time()- start, 2))   
        ax.clear()
        ax.plot(timelog, sensor1,label="Sensor1")
        ax.plot(timelog, sensor2,label="Sensor2")
        ax.plot(timelog, sensor3,label="Sensor3")
        ax.legend(loc='upper right')
        ax.set_title("Moisture")
        ax.set_xlabel('time (s)')
        ax.set_ylabel('Moisture')
        fig.canvas.draw()
    except KeyboardInterrupt:
        print("Keyboard Interrupt")
        break
# Out:
# <img src="data:image/png;base64,..." width="900">
# Keyboard Interrupt

# %% [markdown]
# # Checking for 5 sensors

# %%
#this is the code if you have only 5 sensors.
ser.flushInput()
fig = plt.figure(figsize=(9,5))
ax = fig.add_subplot(111)
ax.set_title("Moisture")
ax.set_xlabel('time (s)')
ax.set_ylabel('Moisture')
sensor1=[]
sensor2=[]
sensor3=[]
sensor4=[]
sensor5=[]
timelog=[]
start = time.time()
while True:
    try:
        ser_bytes = ser.readline()
        ser.close()
        ser.open()
        sensor1.append(int(ser_bytes.split()[0])) 
        sensor2.append(int(ser_bytes.split()[1]))
        sensor3.append(int(ser_bytes.split()[2]))
        sensor4.append(int(ser_bytes.split()[3]))
        sensor5.append(int(ser_bytes.split()[4]))
        timelog.append(round(time.time()- start, 2))   
        ax.clear()
        ax.plot(timelog, sensor1,label="Sensor1")
        ax.plot(timelog, sensor2,label="Sensor2")
        ax.plot(timelog, sensor3,label="Sensor3")
        ax.plot(timelog, sensor4,label="Sensor4")
        ax.plot(timelog, sensor5,label="Sensor5")
        ax.legend(loc='upper right')
        ax.set_title("Moisture")
        ax.set_xlabel('time (s)')
        ax.set_ylabel('Moisture')
        fig.canvas.draw()
    except KeyboardInterrupt:
        print("Keyboard Interrupt")
        break
# Out:
# <img src="data:image/png;base64,..." width="900">
# Keyboard Interrupt

# %%
# Pearson correlation for sensor 1 and sensor 2 is  0.9257112953736222
# Pearson correlation for sensor 1 and sensor 3 is  0.9710325717135505
# Pearson correlation for sensor 1 and sensor 4 is  -0.6294378507295059
# Pearson correlation for sensor 1 and sensor 5 is  -0.7259395879706122
# Pearson correlation for sensor 2 and sensor 3 is  0.9432599001975299
# Pearson correlation for sensor 2 and sensor 4 is  -0.6720104876275175
# Pearson correlation for sensor 2 and sensor 5 is  -0.7818284184364609
# Pearson correlation for sensor 3 and sensor 4 is  -0.7335297815327345
# Pearson correlation for sensor 3 and sensor 5 is  -0.8136268539325029
# Pearson correlation for sensor 4 and sensor 5 is  0.9475167207226025
# Spearman correlation for sensor 1 and sensor 2 is  0.9282624030674587
# Spearman correlation for sensor 1 and sensor 3 is  0.9668387931529892
# Spearman correlation for sensor 1 and sensor 4 is  -0.6747837227666004
# Spearman correlation for sensor 1 and sensor 5 is  -0.7886358004350754
# Spearman correlation for sensor 2 and sensor 3 is  0.9347458308510493
# Spearman correlation for sensor 2 and sensor 4 is  -0.6436469480495607
# Spearman correlation for sensor 2 and sensor 5 is  -0.7702237209400588
# Spearman correlation for sensor 3 and sensor 4 is  -0.7587528304953718
# Spearman correlation for sensor 3 and sensor 5 is  -0.8508631567527415
# Spearman correlation for sensor 4 and sensor 5 is  0.9206499257960732


#For this experiment, I have kept the sensors 3 and 4 in a different mug. So the recordings for sensor 4 and sensor 5 are different and you can observe that based on the negative values in the correlation.

# %%
#this is the code if you have only 5 sensors.
ser.flushInput()
fig = plt.figure(figsize=(9,5))
ax = fig.add_subplot(111)
ax.set_title("Moisture")
ax.set_xlabel('time (s)')
ax.set_ylabel('Moisture')
sensor1=[]
sensor2=[]
sensor3=[]
sensor4=[]
sensor5=[]
timelog=[]
start = time.time()
while True:
    try:
        ser_bytes = ser.readline()
        ser.close()
        ser.open()
        sensor1.append(int(ser_bytes.split()[0])) 
        sensor2.append(int(ser_bytes.split()[1]))
        sensor3.append(int(ser_bytes.split()[2]))
        sensor4.append(int(ser_bytes.split()[3]))
        sensor5.append(int(ser_bytes.split()[4]))
        timelog.append(round(time.time()- start, 2))   
        ax.clear()
        ax.plot(timelog, sensor1,label="Sensor1")
        ax.plot(timelog, sensor2,label="Sensor2")
        ax.plot(timelog, sensor3,label="Sensor3")
        ax.plot(timelog, sensor4,label="Sensor4")
        ax.plot(timelog, sensor5,label="Sensor5")
        ax.legend(loc='upper right')
        ax.set_title("Moisture")
        ax.set_xlabel('time (s)')
        ax.set_ylabel('Moisture')
        fig.canvas.draw()
    except KeyboardInterrupt:
        print("Keyboard Interrupt")
        break
# Out:
# <img src="data:image/png;base64,..." width="900">
# Keyboard Interrupt

# %% [markdown]
# # Correlation of five sensors

# %% [markdown]
# # Pearson correlation

# %%
#  You have 5 Sensors and if you wish to generate the correlation 5C2 

# Generate 5 * 5 matrix and later update the correlation between them. 
list_all = [sensor1,sensor2,sensor3,sensor4,sensor5]
P = [[0 for i in range(6)] for j in range(6)]
S = [[0 for i in range(6)] for j in range(6)]
K = [[0 for i in range(6)] for j in range(6)]
for i in range(1,6):
    for j in range(i+1,6):
#         a = "sensor" + str(i)
#         b = "sensor" + str(j)
#         P[i][j]=sc.pearsonr(print("sensor"+str(i)), print("sensor"+str(j)))[0]
        P[i][j]=sc.pearsonr(list_all[i-1],list_all[j-1])[0]  
        S[i][j]=sc.spearmanr(list_all[i-1],list_all[j-1])[0]
        K[i][j]=sc.kendalltau(list_all[i-1],list_all[j-1])[0]
        print("Pearson correlation for sensor", i, "and sensor", j, "is ", P[i][j])
#         S[i][j]=sc.spearmanr(sensor+str(i), sensor+str(j))[0]

# print("Pearson and Spearman Correlation coefficients are", P)
# Out:
# Pearson correlation for sensor 1 and sensor 2 is  0.9981752898907553
# Pearson correlation for sensor 1 and sensor 3 is  0.9983167821956355
# Pearson correlation for sensor 1 and sensor 4 is  0.8999216045131048
# Pearson correlation for sensor 1 and sensor 5 is  0.8908172368822334
# Pearson correlation for sensor 2 and sensor 3 is  0.9971762603611186
# Pearson correlation for sensor 2 and sensor 4 is  0.8975450895016974
# Pearson correlation for sensor 2 and sensor 5 is  0.8874728352032327
# Pearson correlation for sensor 3 and sensor 4 is  0.9000019579401702
# Pearson correlation for sensor 3 and sensor 5 is  0.8888145608047019
# Pearson correlation for sensor 4 and sensor 5 is  0.9942244924748478

# %% [markdown]
# # Spearman correlation

# %%
for i in range(1,6):
    for j in range(i+1,6):
        print("Spearman correlation for sensor", i, "and sensor", j, "is ", S[i][j])
# Out:
# Spearman correlation for sensor 1 and sensor 2 is  0.9483269353904338
# Spearman correlation for sensor 1 and sensor 3 is  0.9688183879691218
# Spearman correlation for sensor 1 and sensor 4 is  0.8717950690421087
# Spearman correlation for sensor 1 and sensor 5 is  0.8721676289863798
# Spearman correlation for sensor 2 and sensor 3 is  0.9302678393234088
# Spearman correlation for sensor 2 and sensor 4 is  0.8649642317901877
# Spearman correlation for sensor 2 and sensor 5 is  0.8191844254119262
# Spearman correlation for sensor 3 and sensor 4 is  0.8798251588950426
# Spearman correlation for sensor 3 and sensor 5 is  0.8883407862937226
# Spearman correlation for sensor 4 and sensor 5 is  0.8595743777278553

# %% [markdown]
# # Kendall’s Tau correlation

# %% [markdown]
# The Kendall’s Tau correlation is a non-parametric test that does not make any assumptions about the distribution of the data. The only assumption is:
#
# There should be a monotonic relationship between the variables being tested

# %%
for i in range(1,6):
    for j in range(i+1,6):
        print("Kendall Tau correlation for sensor", i, "and sensor", j, "is ", K[i][j])
# Out:
# Kendall Tau correlation for sensor 1 and sensor 2 is  0.8857708689693606
# Kendall Tau correlation for sensor 1 and sensor 3 is  0.9188146985466923
# Kendall Tau correlation for sensor 1 and sensor 4 is  0.7505077111067868
# Kendall Tau correlation for sensor 1 and sensor 5 is  0.7630020842540554
# Kendall Tau correlation for sensor 2 and sensor 3 is  0.8460477803187728
# Kendall Tau correlation for sensor 2 and sensor 4 is  0.7525729031181808
# Kendall Tau correlation for sensor 2 and sensor 5 is  0.6948303782323854
# Kendall Tau correlation for sensor 3 and sensor 4 is  0.7598015070208849
# Kendall Tau correlation for sensor 3 and sensor 5 is  0.7845402020968207
# Kendall Tau correlation for sensor 4 and sensor 5 is  0.762164403592269

# %% [markdown]
# # For this experiment, I have kept the sensors 3 and 4 in a different mug. So the recordings for sensor 4 and sensor 5 are different and you can observe that based on the negative values in the correlation.

# %% [markdown]
# # Sensor recording to csv

# %%
import csv
with open("data.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(list_all)

# You can get the data in 5 rows 
# For python 2 , you have to use wb

# %%
map1={}
map1['Sensor1']=list_all[0]
map1['Sensor2']=list_all[1]
map1['Sensor3']=list_all[2]
map1['Sensor4']=list_all[3]
map1['Sensor5']=list_all[4] 
df = pd.DataFrame.from_dict(map1)
df.to_csv('data_vertical.csv')

# http://pbpython.com/pandas-list-dict.html

# %%
# To establish communication from the computer to the micro controller.
# How to establish a connection between the computer to the

# %%
# Serial.write from the system and then the serial.read to the micro controller.

# %% [markdown]
# # Serial communication establishment:-                                                                                                                                                                                                            Computer will write and will make serial.available to active,                                                                                                                                                                     then the microcontroller will read and checks if it matches with the value,            it will print the data on serial port.

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import scipy.stats as sc
import serial
import pandas as pd
from serial import Serial
# ser.close()
ser = serial.Serial('COM4', 9600)
ser.flushInput()
sensor1=[]
sensor2=[]
sensor3=[]
timelog=[]
start = time.time()
while True:
    try:
        ser.close()
        ser.open()
        ser_bytes = ser.readline()
        if (int(ser_bytes.split()[0]) or int(ser_bytes.split()[4]) or int(ser_bytes.split()[1]) or int(ser_bytes.split()[2]) or int(ser_bytes.split()[3])) > 600:
            ser.write(b'a')
            print("Alerting by writing on serial port and the led light should blink") 
#           You are adding extra delay such that the value is more. 
            time.sleep(1)
    #Since Im writing only 3 letters I could say that 
            if ser.readline().decode('ascii')[0:3] == 'yes':
                print("Arduino received the data and it has alerted through led")
        sensor1.append(int(ser_bytes.split()[0])) 
        sensor2.append(int(ser_bytes.split()[1]))
        sensor3.append(int(ser_bytes.split()[2]))
    except KeyboardInterrupt:
        print("Keyboard Interrupt")
        ser.close()
        break

# %%
#Make sure that the data_vertical is in the same folder.

# %% [markdown]
# # Generation of the correlation matrix

# %%
import pandas as pd
import scipy.stats as sc
df=pd.read_csv('data_vertical.csv')
list_all=[df['Sensor1'].values,df['Sensor2'].values,df['Sensor3'].values,df['Sensor4'].values,df['Sensor5'].values ]
# data_vertical.csv contains the values for the five sensors
# list_all = [sensor1,sensor2,sensor3,sensor4,sensor5]
P = [[0 for i in range(5)] for j in range(5)]
S = [[0 for i in range(5)] for j in range(5)]
K = [[0 for i in range(5)] for j in range(5)]
for i in range(5):
    for j in range(i,5):
        P[i][j]=sc.pearsonr(list_all[i],list_all[j])[0]  
        S[i][j]=sc.spearmanr(list_all[i],list_all[j])[0]
        K[i][j]=sc.kendalltau(list_all[i],list_all[j])[0]
        P[j][i]= P[i][j]
        S[j][i]= S[i][j]
        K[j][i]= K[i][j]
        print("Pearson correlation for sensor", i+1, "and sensor", j+1, "is ", P[i][j])
# Out:
# Pearson correlation for sensor 1 and sensor 1 is  1.0
# Pearson correlation for sensor 1 and sensor 2 is  0.9981752898907553
# Pearson correlation for sensor 1 and sensor 3 is  0.9983167821956355
# Pearson correlation for sensor 1 and sensor 4 is  0.8999216045131048
# Pearson correlation for sensor 1 and sensor 5 is  0.8908172368822334
# Pearson correlation for sensor 2 and sensor 2 is  1.0
# Pearson correlation for sensor 2 and sensor 3 is  0.9971762603611186
# Pearson correlation for sensor 2 and sensor 4 is  0.8975450895016974
# Pearson correlation for sensor 2 and sensor 5 is  0.8874728352032327
# Pearson correlation for sensor 3 and sensor 3 is  1.0
# Pearson correlation for sensor 3 and sensor 4 is  0.9000019579401702
# Pearson correlation for sensor 3 and sensor 5 is  0.8888145608047019
# Pearson correlation for sensor 4 and sensor 4 is  1.0
# Pearson correlation for sensor 4 and sensor 5 is  0.9942244924748478
# Pearson correlation for sensor 5 and sensor 5 is  1.0

# %%
from IPython.display import Image
Image('Fuzzy.png',width=800, height=1200)

# %% [markdown]
# # Function to take a correlation matrix value and process them using fixed fuzzy system and then computing the matrix.

# %%
def fun(correlation,membership,values):
    '''
    correlation matrix n*n symmetric matrix
    So its better to compute for half of the values. 
    In rectangle due to symmetry the sum of the y values is equal to 1.
    membership is nothing but similar to the membermembership function--- [x1 x2 x3 x4]
    Right now, I'm defining only between two things. 
    y=0 and  y=1 for some x1 and x2
    y=1 and  y=0 for the same x1 and x2 
    I have to define four lines for two different ranges. 
    So taking the arguments in membermembership function as (x1,x2) for the intersection of the Weak and Medium
    (x3,x4) for the intersection of Medium and Strong. 
    It should output the values Weak*possibility_Weak +  Medium*possibility_Medium + Strong*possibility_Strong
    values---[Weak, Medium, Strong]
    '''
    K=[[0 for j in range(len(correlation))] for i in range(len(correlation))]
    for i in range(len(correlation)):
        for j in range(i,len(correlation)):
            Possibility=[0,0,0]
            if correlation[i][j] <= membership[0] :
                Possibility[0]=1
            elif (correlation[i][j] > membership[0]) and (correlation[i][j] < membership[1]):
                Possibility[0]=(correlation[i][j])/(membership[0]- membership[1]) - (membership[1])/(membership[0]- membership[1])
                Possibility[1] = 1- Possibility[0]
                #Possibility[1]=-( (correlation[i][j])/(membership[0]- membership[1]) - (membership[0])/(membership[0]- membership[1]))
            elif (correlation[i][j] >= membership[1]) and (correlation[i][j] <= membership[2]):
                Possibility[1]=1
            elif (correlation[i][j] > membership[2]) and (correlation[i][j] < membership[3]):
                Possibility[1]=(correlation[i][j])/(membership[2]- membership[3]) - (membership[3])/(membership[2]- membership[3])
                Possibility[2]=1- Possibility[1]
            elif (correlation[i][j] >= membership[3]) and (correlation[i][j] <= 1):
                Possibility[2]= 1
            else:
                print("Invalid Input")
                break
            total=0
            for k in range(len(Possibility)):
                total+=Possibility[k]*values[k]
            K[i][j]=total
            K[j][i]=total
    return K
membership=[0.88,0.895,0.9,0.95]
# membership=[0.2,0.3,0.8,0.86]
values=[0,1,2]
print("Pearson correlation coefficient")
print(fun(P,membership,values))
print("Spearman correlation coefficient")
print(fun(S,membership,values))
print("Kendall’s Tau correlation coefficient")
print(fun(K,membership,values))
# Out:
# Pearson correlation coefficient
# [[2, 2, 2, 1, 0.7211491254822207], [2, 2, 2, 1, 0.4981890135488456], [2, 2, 2, 1.0000391588034034, 0.587637386980127], [1, 1, 1.0000391588034034, 2, 2], [0.7211491254822207, 0.4981890135488456, 0.587637386980127, 2, 2]]
# Spearman correlation coefficient
# [[2, 1.9665387078086773, 2, 0, 0], [1.9665387078086773, 2, 1.6053567864681781, 0, 0], [2, 1.6053567864681781, 2, 0, 0.5560524195815049], [0, 0, 0, 2, 0], [0, 0, 0.5560524195815049, 0, 2]]
# Kendall’s Tau correlation coefficient
# [[2, 0.3847245979573728, 1.376293970933844, 0, 0], [0.3847245979573728, 2, 0, 0, 0], [1.376293970933844, 0, 2, 0, 0], [0, 0, 0, 2, 0], [0, 0, 0, 0, 2]]

# %%
# def ToRatio(value, leftMin=1023, leftMax=465, rightMin=0, rightMax=100):
#     leftSpan = leftMax - leftMin
#     rightSpan = rightMax - rightMin

#     # Convert the left range into a 0-1 range (float)
#     valueScaled = float(value - leftMin) / float(leftSpan)

#     # Convert the 0-1 range into a value in the right range.
#     return rightMin + (valueScaled * rightSpan)
# ser.flushInput()
# fig = plt.figure(figsize=(9,5))
# ax = fig.add_subplot(111)
# ax.set_title("Moisture")
# ax.set_xlabel('time (s)')
# ax.set_ylabel('Moisture')
# plt.ion()
# moistlog = []
# timelog = []
# start = time.time()
# while True:
#     try:
#         ser_bytes = ser.readline()
#         decoded_bytes = float(ser_bytes[0:len(ser_bytes)-2].decode("utf-8"))
#         moistlog.append(ToRatio(decoded_bytes)) 
#         timelog.append(round(time.time()- start, 2))
#         if len(moistlog) > 100:
#             del moistlog[0]
#             del timelog[0]        
#         ax.clear()
#         ax.plot(timelog, moistlog)
#         ax.set_title("Moisture")
#         ax.set_xlabel('time (s)')
#         ax.set_ylabel('Moisture')
#         fig.canvas.draw()
#     except KeyboardInterrupt:
#         print("Keyboard Interrupt")
#         break
